# %% [markdown]
# # Pinwheel Tiling

# %%
import time
from pinwheel import *

# %%
from pinwheel import *

# %% [markdown]
# Start with the prototile:

# %%
tiling = pinwheel()
tiling.patch
# Out:
# <img src="data:image/svg+xml;base64,...">

# %%
# set the desired number of iterations
N = 5

# %% [markdown]
# Inflate and subdivide:

# %%
# run this cell to do a subsitution!
tiling.sub(N)
tiling.patch
# Out:
# <img src="data:image/svg+xml;base64,...">

# %% [markdown]
# Save the SVG:

# %%
# uncomment to save
path = 'patch_'+time.strftime("%Y%m%d-%H%M%S")+'.svg'
#tiling.save(path)
